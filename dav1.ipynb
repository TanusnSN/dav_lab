# %% [markdown]
# <a href="https://colab.research.google.com/github/TanusnSN/dav_lab/blob/main/dav1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from statistics import mode
arr = np.array([10, 20, 30, 40, 50])
print("Array:",arr)
mean=np.mean(arr)
median=np.median(arr)
print("Mean:",mean)
print("Median:",median)
print("Mode:",mode(arr))
print("Reshaped 2D:\n",arr.reshape(5,1))
print("Sliced (index 1 to 3):", arr[1:4])


#---Create a DataFrame--
data={"Name":["Asha","Ravi","Meera","Karan"],
      "Marks":[98,97,92,89],
      "Branch":["CSE","CSE","ECE","CSE"]}
df=pd.DataFrame(data)
print(df)


#---Indexing and slicing---
print("\nFirst 2 rows:\n",  df.iloc[0:2])
print("\nMarks column:\n", df["Marks"])
print("\nRows where Marks > 90:\n", df[df["Marks"]>90])
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Median: 30.0
# Mode: 10
# Reshaped 2D:
#  [[10]
#  [20]
#  [30]
#  [40]
#  [50]]
# Sliced (index 1 to 3): [20 30 40]
#     Name  Marks Branch
# 0   Asha     98    CSE
# 1   Ravi     97    CSE
# 2  Meera     92    ECE
# 3  Karan     89    CSE
#
# First 2 rows:
#     Name  Marks Branch
# 0  Asha     98    CSE
# 1  Ravi     97    CSE
#
# Marks column:
#  0    98
# 1    97
# 2    92
# 3    89
# Name: Marks, dtype: int64
#
# Rows where Marks > 90:
#      Name  Marks Branch
# 0   Asha     98    CSE
# 1   Ravi     97    CSE
# 2  Meera     92    ECE
